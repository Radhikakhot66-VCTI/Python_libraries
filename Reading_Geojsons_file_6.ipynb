# %%
import geopandas as gpd
from geopandas import GeoDataFrame

gdf1= gpd.read_file("/content/soil_data_be 3.geojson")
gdf2= gpd.read_file("/content/VCTI_abc_network 5 1.geojson")

# %%
print(gdf1.head())
print(gdf1.columns)
# Out:
#     GeoIQ_ID state countyfp area_cod                        stcnt_name  \
# 0  PA095_409    PA    42095    PA095  Northampton County, Pennsylvania
# 1  PA095_410    PA    42095    PA095  Northampton County, Pennsylvania
# 2  PA095_411    PA    42095    PA095  Northampton County, Pennsylvania
# 3  PA095_412    PA    42095    PA095  Northampton County, Pennsylvania
# 4  PA095_416    PA    42095    PA095  Northampton County, Pennsylvania
#
#   final_hard rock_class  hard_class  top_dep  bot_dep  ...  \
# 0          2  Soft Rock  Hardness 2        0       12  ...
# 1          2  Soft Rock  Hardness 2       12       24  ...
# 2          2  Soft Rock  Hardness 2       24       36  ...
# 3          5  Hard Rock  Hardness 5       36       48  ...
# 4          2  Soft Rock  Hardness 2        0       12  ...
#
#                tx_def w_ptex_vol    sc_name sc_kind  \
# 0  Channery Silt Loam      30.86  Bedington  Series
# 1  Channery Silt Loam      34.00  Bedington  Series
# ...

# %%
print(gdf2.head())
print(gdf2.columns)
# Out:
#    id                                               icon          name  \
# 0  16  http://maps.google.com/mapfiles/kml/pushpin/yl...   SR-S19-Bore
# 1  15  http://maps.google.com/mapfiles/kml/pushpin/yl...     SR-S18-RR
# 2  14  http://maps.google.com/mapfiles/kml/pushpin/yl...  SR-S17-Water
# 3  13  http://maps.google.com/mapfiles/kml/pushpin/yl...   SR-S16-Bore
# 4  12  http://maps.google.com/mapfiles/kml/pushpin/yl...     SR-S15-HW
#
#     stroke              styleUrl styleHash  stroke-width  \
# 0  #0000ff  #msn_ylw-pushpin3730  641b3642             4
# 1  #0000ff  #msn_ylw-pushpin3730  641b3642             4
# 2  #0000ff  #msn_ylw-pushpin3730  641b3642             4
# 3  #0000ff  #msn_ylw-pushpin3730  641b3642             4
# 4  #0000ff  #msn_ylw-pushpin3730  641b3642             4
#
#                                         styleMapHash  stroke-opacity  \
# 0  { "normal": "#sn_ylw-pushpin0140", "highlight"...               1
# ...

# %%
pip install fiona
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 32.8 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd
import fiona
from shapely.geometry import shape
import matplotlib.pyplot as plt

# %%
fig, ax=plt.subplots(figsize=(10,6))
gdf1.plot(ax=ax, color="lightgreen", edgecolor="blue", alpha=0.5)
gdf2.plot(ax=ax, color="red")
plt.title("Soil vs Network Map")
plt.show()

# %%
print(gdf1.crs)
print(gdf2.crs)
# Out:
# EPSG:4326
# EPSG:4326

# %%
gdf1.plot()
# Out:
# <Axes: >

# %%
gdf2.plot()
# Out:
# <Axes: >

# %%
gdf1['hard_class'].unique()
# Out:
# array(['Hardness 2', 'Hardness 5', 'Loamy Soil', 'Sand', 'Hardness 1',
#        'Hardness 4', 'Hardness 3', 'Hardness 7', 'Water', 'Misc Areas',
#        'Hardness 8'], dtype=object)

# %%
gdf1['countyfp'].unique()
# Out:
# array(['42095', '34019', '34041'], dtype=object)
