# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhikakhot66-VCTI/Python_libraries/blob/Pavan/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geodatasets --quiet

# %%
import geodatasets

# %%
import geopandas

# %%
colombia = geopandas.read_file(geodatasets.get_path('geoda.malaria'))
# Out:
# ...
# Extracting 'malariacolomb/colmunic.gpkg' from '/root/.cache/geodatasets/malariacolomb.zip' to '/root/.cache/geodatasets/malariacolomb.zip.unzip'

# %%
colombia.head()
# Out:
#    ID      ADM0       ADM1        ADM2 CODDEPT  IDDANE DANECODE  TP1973  \
# 0   1  COLOMBIA    Guajira      URIBIA      44   44847    44847   57815
# 1   2  COLOMBIA    Guajira     MANAURE      44   44560    44560    5661
# 2   3  COLOMBIA    Guajira      MAICAO      44   44430    44430   36771
# 3   4  COLOMBIA    Guajira    RIOHACHA      44   44001    44001   46024
# 4   5  COLOMBIA  Magdalena  SITIONUEVO      47   47745    47745   16493
#
#    UP1973  RP1973  ...  TP2003  UP2003  RP2003  TP2004  UP2004  RP2004  \
# 0    2881   54934  ...   67709    6682   61027   68458    7053   61405
# 1    4074    1587  ...   42371    8548   33823   44229    9096   35133
# 2   25161   11610  ...  140121  122435   17686  144277  126249   18028
# 3   22545   23479  ...   98318   90883    7435   98909   91408    7501
# 4    6289   10204  ...   21058   11646    9412   21101   11723    9378
#
#    TP2005  UP2005  RP2005                                           geometry
# ...

# %%
colombia.plot(markersize=.5);

# %%
colombia['centroid_column'] = colombia.centroid
# Out:
# /tmp/ipython-input-9-2784515387.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   colombia['centroid_column'] = colombia.centroid

# %%
colombia = colombia.set_geometry('centroid_column')

# %%
colombia.plot();

# %%
url = "http://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_land.geojson"
df = geopandas.read_file(url)

# %%
df.head()
# Out:
#    scalerank featureclass                                           geometry
# 0          1      Country  POLYGON ((-59.57209 -80.04018, -59.86585 -80.5...
# 1          1      Country  POLYGON ((-159.20818 -79.49706, -161.1276 -79....
# 2          1      Country  POLYGON ((-45.15476 -78.04707, -43.92083 -78.4...
# 3          1      Country  POLYGON ((-121.21151 -73.50099, -119.91885 -73...
# 4          1      Country  POLYGON ((-125.55957 -73.48135, -124.03188 -73...

# %%
df.plot()
# Out:
# <Axes: >

# %%
import geodatasets

gdf_mask = geopandas.read_file(
    geodatasets.get_path("geoda.nyc")
)
gdf = geopandas.read_file(
    geodatasets.get_path("geoda.nyc education"),
    mask=gdf_mask[gdf_mask.name=="Coney Island"],
)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf_mask.plot()
# Out:
# <Axes: >

# %%
bbox = (
    1031051.7879884212, 224272.49231459625, 1047224.3104931959, 244317.30894023244
)
gdf = geopandas.read_file(
    geodatasets.get_path("nybb"),
    bbox=bbox,
)
# Out:
# ...
# Extracting 'nybb_16a/nybb.shp' from '/root/.cache/geodatasets/nybb_16a.zip' to '/root/.cache/geodatasets/nybb_16a.zip.unzip'
# Extracting 'nybb_16a/nybb.shx' from '/root/.cache/geodatasets/nybb_16a.zip' to '/root/.cache/geodatasets/nybb_16a.zip.unzip'
# Extracting 'nybb_16a/nybb.dbf' from '/root/.cache/geodatasets/nybb_16a.zip' to '/root/.cache/geodatasets/nybb_16a.zip.unzip'
# Extracting 'nybb_16a/nybb.prj' from '/root/.cache/geodatasets/nybb_16a.zip' to '/root/.cache/geodatasets/nybb_16a.zip.unzip'

# %%
gdf.plot()
# Out:
# <Axes: >
